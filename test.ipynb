# %%
from ultralytics import YOLO

# %%
model_file = 'C:\\Users\\owend\\Projects\\Eye_tracker\\runs\detect\\train2\weights\\best.pt'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\owend\AppData\Local\Temp\ipykernel_7276\1700761337.py:1: SyntaxWarning: invalid escape sequence '\d'
#   model_file = 'C:\\Users\\owend\\Projects\\Eye_tracker\\runs\detect\\train2\weights\\best.pt'

# %%
print(model_file)
# Out:
# C:\Users\owend\Projects\Eye_tracker\runs\detect\train2\weights\best.pt

# %%
model = YOLO(model_file)

# %%
import cv2
import numpy as np

# %%
model = YOLO("C:\\Users\\owend\\Projects\\Eye_tracker\\runs\\detect\\train2\\weights\\best.pt")  # .pt file from training

# Open the webcam (or use a video file)
cap = cv2.VideoCapture(1)  # or 'your_video.mp4'

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO inference on the frame
    results = model(frame)

    # Loop through detections and draw boxes
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box
            conf = float(box.conf[0])               # Confidence
            cls = int(box.cls[0])                   # Class id
            label = model.names[cls]                # Class name

            # Draw the bounding box and label
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow('YOLOv11 Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x640 1 pupil, 77.1ms
# Speed: 1.8ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 55.6ms
# Speed: 1.1ms preprocess, 55.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 58.5ms
# Speed: 1.2ms preprocess, 58.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 pupil, 57.4ms
# ...
